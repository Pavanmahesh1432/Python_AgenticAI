# %% [markdown]
# <center> <h1>📍📍 Variables and Data Types 📍📍</h1> </center>

# %% [markdown]
# ---
#
# ###  📍 Variable Assignment
#
#
# - When you create a variable you keep some space in memory. These memory locations are then used to store values.
#
#
#
# ---

# %%
# define a variable name "a" and assign value 5 to it
a = 5

# %%
# print the value of variable
a
# Out:
# 5

# %% [markdown]
# - To view some data on the output screen, python also has `print` function.
# - Using `print` function we can control the view on the output screen.
#
# ---

# %%
print(a)
# Out:
# 5

# %% [markdown]
# ### 📍 How variables work in Python
#
# ---

# %%
# Look at the following statements
a = 7
b = a
a = 3

# %% [markdown]
# ***What will be the value of a?***
#
#
# ---

# %%
print(a)
# Out:
# 3

# %%
print(b)
# Out:
# 7

# %% [markdown]
# ### 📍 Variable naming rules
#
#
# ---
# ***Identifiers in Python***
#
# * Like Variables, we have to define functions, classes, etc in python. Naming them helps to differentiate one entity from another.
# * All these names given to these entities are known as `Identifiers`.
# * Python have some rules to define the Identifiers.
#
#
# ***Rules of Writing Identifiers***
#
# * Python is case sensitive language.
# * Identifiers can be a combination of letters in lowercase (a to z) or uppercase (A to Z) or digits (0 to 9) or an underscore _.
# * Names like myVariable, var_1 and print_this, all are valid example.
# * An identifier cannot start with a digit.
# * `1variable` is invalid, but `variable1` is perfectly fine.
# * We cannot use special symbols like !, @, #, $, % etc. in our identifier. `_` is allowed.
#
# * ***`Keywords` cannot be used as identifiers. `Keywords` are the reserved words in Python.***

# %% [markdown]
# ---
#
# ***Keywords in Python***
#
# ---
#
# * False
# * class
# * finally
# * is
# * return
# * None
# * continue
# * for
# * lambda
# * try
# * True, etc
#
#
# ---

# %% [markdown]
# ---
#
# ***Python is case sensitive so `a` and `A` are different***
#
# ---

# %%
A = 4
a = 400

# %%
print(a)
print(A)
# Out:
# 400
# 4

# %% [markdown]
# ***Rules to define variable names***
#
# ---

# %%
# allowed
a = 5

# %%
# only "_" underscore is allowed in allowed in special characters in the variable name
_a = 5

# %%
a_ = 500

# %%
# other special characters are not allowed
@a=5
# Out:
#   Cell In[36], line 2
#     @a=5
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
# we can not start with variables name with a number
1a = 5
# Out:
#   Cell In[38], line 2
#     1a = 5
#     ^
# SyntaxError: invalid decimal literal

# %%
a1 = 500

# %% [markdown]
# ---
#
#
# ###  📍 Data types
#
# * int
# * string
# * float
# * bool
#
# ---

# %%
# INTEGER TYPE
a = 5

# %%
type(a)
# Out:
# int

# %%
# STRING TYPE
b = "lakshay"

# %%
type(b)
# Out:
# str

# %%
# FLOAT TYPE
c = 5.55

# %%
# BOOLEAN TYPE
d = True

# %%
e = False

# %%
type(d), type(e)
# Out:
# (bool, bool)

# %%
whos
# Out:
# Variable               Type        Data/Info
# --------------------------------------------
# A                      int         4
# a                      int         5
# a1                     int         500
# a_                     int         500
# b                      str         lakshay
# c                      float       5.55
# d                      bool        True
# dataframe_columns      function    <function dataframe_colum<...>ns at 0x0000020E8B7B0400>
# dataframe_hash         function    <function dataframe_hash at 0x0000020E8B7B0900>
# dtypes_str             function    <function dtypes_str at 0x0000020E8B7B0860>
# e                      bool        False
# get_dataframes         function    <function get_dataframes at 0x0000020E8B7B05E0>
# getpass                module      <module 'getpass' from 'C<...>conda3\\Lib\\getpass.py'>
# hashlib                module      <module 'hashlib' from 'C<...>conda3\\Lib\\hashlib.py'>
# import_pandas_safely   function    <function import_pandas_s<...>ly at 0x0000020E8B7B0360>
# is_data_frame          function    <function is_data_frame at 0x0000020E8B7B0C20>
# json                   module      <module 'json' from 'C:\\<...>\Lib\\json\\__init__.py'>

# %% [markdown]
# ---
#
# ### 📍 Type Conversion
#
#
# ***Python defines type conversion functions to directly convert one data type to another.***
#
#
#
# ---

# %%
# age is generally in integer numbers
my_age = 26.33333
my_age = int(my_age)
my_age
# Out:
# 26

# %% [markdown]
# ***convert string to integer***
#
# ---

# %%
# if we try to add string and integer number, it will give an error
my_int = '2' + 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 2
#       1 # if we try to add string and integer number, it will give an error
# ----> 2 my_int = '2' + 6
#
# TypeError: can only concatenate str (not "int") to str

# %%
# type conversion: string to int
my_int = int('2') + 6
my_int
# Out:
# 8

# %%
type(my_int)
# Out:
# int
